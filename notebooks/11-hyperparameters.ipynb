# %%
import io
import os
import pathlib
import requests
import tarfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import sparse
from sklearn import dummy, ensemble, feature_extraction, metrics, model_selection, pipeline, preprocessing, tree
import xgboost as xgb
import yellowbrick

# %%
DATA_ARCHIVE = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
DATA_DIR = pathlib.Path("./sample_data")

response = requests.get(DATA_ARCHIVE, stream=True)
with tarfile.open(fileobj=response.raw, mode="r|gz") as t:
    t.extractall(DATA_DIR)

# %%
def _reviews_to_df(filepath, sentiment):
    d = {"text": [], "sentiment": []}
    review_filepaths = sorted(filepath.glob("*.txt"))
    for review_filepath in review_filepaths:
        with open(review_filepath, 'r') as f:
            review = f.read()
        d["text"].append(review)
        d["sentiment"].append("positive" if sentiment == "pos" else "negative")
    df = pd.DataFrame.from_dict(d)
    return df


def _combine_reviews():
    dfs = []
    for split in ["train", "test"]:
        for sentiment in ["pos", "neg"]:
            df = _reviews_to_df(DATA_DIR / "aclImdb" / split / sentiment, sentiment)
            dfs.append(df)
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df


def partition_reviews(seed=42, test_size=0.2):
    combined_df = _combine_reviews()
    random_state = np.random.RandomState(seed)
    train_df, _val_df = model_selection.train_test_split(
        combined_df,
        random_state=random_state,
        shuffle=True,
        stratify=combined_df["sentiment"],
        test_size=test_size
    )

    # split the _val_df equally into val and test sets
    val_df, test_df = model_selection.train_test_split(
        _val_df,
        random_state=random_state,
        shuffle=True,
        stratify=_val_df["sentiment"],
        test_size=0.5
    )

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = partition_reviews(seed=42)

# %%
vectorizer_hyperparams = {
    "lowercase": True,
    "max_df": 0.9, # ignore words that show up in more than 90% of reviews
    "min_df": 0.1, # ignore words than show up in less than 10% of reviews
    "norm": "l2", # normalize rows using
    "dtype": np.float32,
}

features_preprocessing = pipeline.make_pipeline(
    feature_extraction.text.TfidfVectorizer(
        **vectorizer_hyperparams,
    ),
    preprocessing.FunctionTransformer(lambda csr: csr.toarray(), lambda arr: sparse.csr_matrix(arr))
)

label_encoder = preprocessing.LabelEncoder()

# %%
X_train = features_preprocessing.fit_transform(train_df.loc[:, "text"])
y_train = label_encoder.fit_transform(train_df.loc[:, "sentiment"])

X_val = features_preprocessing.transform(val_df.loc[:, "text"])
y_val = label_encoder.fit_transform(val_df.loc[:, "sentiment"])

X_test = features_preprocessing.transform(test_df.loc[:, "text"])
y_test = label_encoder.fit_transform(test_df.loc[:, "sentiment"])

# %%
xgb.XGBClassifier?

# %%
xgb_classifier = xgb.XGBClassifier(random_state=42)
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
print(f"Training accuracy: {xgb_classifier.score(X_train, y_train)}")
print(f"Validation accuracy: {xgb_classifier.score(X_val, y_val)}")
# Out:
# Training accuracy: 0.910925
# Validation accuracy: 0.7668

# %%
from yellowbrick.model_selection import validation_curve


_ = validation_curve(
    xgb.XGBClassifier(),
    X=np.vstack([X_train, X_val]),
    y=np.hstack([y_train, y_val]),
    param_name="gamma",
    param_range=[0, 0.5, 1, 5, 10, 20, 30],
    scoring="accuracy",
    cv=3,
    n_jobs=-1,
    verbose=1,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-30abec37b1db> in <cell line: 4>()
#       2
#       3
# ----> 4 _ = validation_curve(
#       5     xgb.XGBClassifier(),
#       6     X=np.vstack([X_train, X_val]),
#
# /usr/local/lib/python3.10/dist-packages/yellowbrick/model_selection/validation_curve.py in validation_curve(estimator, X, y, param_name, param_range, ax, logx, groups, cv, scoring, n_jobs, pre_dispatch, show, markers, **kwargs)
#     420
#     421     # Fit the visualizer
# --> 422     oz.fit(X, y)
#     423
#     424     # Draw final visualization
#
# /usr/local/lib/python3.10/dist-packages/yellowbrick/model_selection/validation_curve.py in fit(self, X, y)
#     231
#     232         # compute the validation curve and store scores
# --> 233         curve = sk_validation_curve(self.estimator, X, y, **skvc_kwargs)
#     234         self.train_scores_, self.test_scores_ = curve
#     235
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in validation_curve(estimator, X, y, param_name, param_range, groups, cv, scoring, n_jobs, pre_dispatch, verbose, error_score, fit_params)
#    1874
#    1875     parallel = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch, verbose=verbose)
# -> 1876     results = parallel(
#    1877         delayed(_fit_and_score)(
#    1878             clone(estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1853             output = self._get_sequential_output(iterable)
#    1854             next(output)
# -> 1855             return output if self.return_generator else list(output)
#    1856
#    1857         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1782                 self.n_dispatched_batches += 1
#    1783                 self.n_dispatched_tasks += 1
# -> 1784                 res = func(*args, **kwargs)
#    1785                 self.n_completed_tasks += 1
#    1786                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1488             )
#    1489
# -> 1490             self._Booster = train(
#    1491                 params,
#    1492                 train_dmatrix,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183         if cb_container.before_iteration(bst, i, dtrain, evals):
#     184             break
# --> 185         bst.update(dtrain, i, obj)
#     186         if cb_container.after_iteration(bst, i, dtrain, evals):
#     187             break
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1916
#    1917         if fobj is None:
# -> 1918             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                                     ctypes.c_int(iteration),
#    1920                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
xgb_classifier = xgb.XGBClassifier(learning_rate=1, max_depth=2, random_state=42)
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
_vocabulary = features_preprocessing["tfidfvectorizer"].vocabulary_
_by_values = sorted(_vocabulary.items(), key=lambda item: item[1])
feature_names = [k for k, _ in _by_values]

xgb_classifier.get_booster().feature_names = feature_names
_ = xgb.plot_tree(
    xgb_classifier,
    num_trees=0,
)

# %%
xgb_classifier = xgb.XGBClassifier(learning_rate=1e-3, max_depth=2, random_state=42)
xgb_classifier.fit(X_train, y_train)

xgb_classifier.get_booster().feature_names = feature_names
_ = xgb.plot_tree(
    xgb_classifier,
    num_trees=0,
)

# %%
hyperparam_grid = {
    "reg_lambda": [0.0],
    "learning_rate": [0.1, 0.3],
    "max_depth": [1, 2, 4],
    "subsample": [0.75, 1],
    "colsample_by_tree": [0.8, 1],
    "min_samples_split": [2, 4],
    "random_state": [42],
    "n_jobs": [-1],
    "n_estimators": [200],
    "early_stopping_rounds": [5],
}

grid_search_cv = model_selection.GridSearchCV(
    xgb.XGBClassifier(),
    param_grid=hyperparam_grid,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    verbose=1,
)

_ = grid_search_cv.fit(
    X_train,
    y_train,
    eval_set=[
        (X_val, y_val)
    ],
)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [14:37:27] WARNING: ../src/learner.cc:767:
# Parameters: { "colsample_by_tree", "min_samples_split" } are not used.
#
# [0]	validation_0-logloss:0.67849
# [1]	validation_0-logloss:0.66712
# [2]	validation_0-logloss:0.65635
# [3]	validation_0-logloss:0.64747
# [4]	validation_0-logloss:0.64000
# [5]	validation_0-logloss:0.63369
# [6]	validation_0-logloss:0.62765
# [7]	validation_0-logloss:0.62286
# [8]	validation_0-logloss:0.61828
# [9]	validation_0-logloss:0.61415
# [10]	validation_0-logloss:0.61067
# [11]	validation_0-logloss:0.60784
# [12]	validation_0-logloss:0.60435
# [13]	validation_0-logloss:0.60063
# [14]	validation_0-logloss:0.59800
# [15]	validation_0-logloss:0.59514
# [16]	validation_0-logloss:0.59271
# [17]	validation_0-logloss:0.58954
# [18]	validation_0-logloss:0.58722
# [19]	validation_0-logloss:0.58483
# [20]	validation_0-logloss:0.58266
# [21]	validation_0-logloss:0.58015
# [22]	validation_0-logloss:0.57798
# [23]	validation_0-logloss:0.57620
# [24]	validation_0-logloss:0.57434
# [25]	validation_0-logloss:0.57271
# [26]	validation_0-logloss:0.57068
# [27]	validation_0-logloss:0.56887
# [28]	validation_0-logloss:0.56699
# [29]	validation_0-logloss:0.56512
# [30]	validation_0-logloss:0.56328
# [31]	validation_0-logloss:0.56144
# [32]	validation_0-logloss:0.55975
# [33]	validation_0-logloss:0.55796
# [34]	validation_0-logloss:0.55662
# [35]	validation_0-logloss:0.55550
# [36]	validation_0-logloss:0.55386
# [37]	validation_0-logloss:0.55225
# [38]	validation_0-logloss:0.55086
# [39]	validation_0-logloss:0.54970
# [40]	validation_0-logloss:0.54853
# [41]	validation_0-logloss:0.54712
# [42]	validation_0-logloss:0.54582
# [43]	validation_0-logloss:0.54484
# [44]	validation_0-logloss:0.54379
# [45]	validation_0-logloss:0.54261
# [46]	validation_0-logloss:0.54154
# [47]	validation_0-logloss:0.54054
# [48]	validation_0-logloss:0.53971
# [49]	validation_0-logloss:0.53888
# [50]	validation_0-logloss:0.53783
# [51]	validation_0-logloss:0.53686
# [52]	validation_0-logloss:0.53584
# [53]	validation_0-logloss:0.53488
# [54]	validation_0-logloss:0.53395
# [55]	validation_0-logloss:0.53303
# [56]	validation_0-logloss:0.53250
# [57]	validation_0-logloss:0.53179
# [58]	validation_0-logloss:0.53105
# [59]	validation_0-logloss:0.53028
# [60]	validation_0-logloss:0.52939
# [61]	validation_0-logloss:0.52832
# [62]	validation_0-logloss:0.52757
# [63]	validation_0-logloss:0.52668
# [64]	validation_0-logloss:0.52596
# [65]	validation_0-logloss:0.52519
# [66]	validation_0-logloss:0.52429
# [67]	validation_0-logloss:0.52353
# [68]	validation_0-logloss:0.52304
# [69]	validation_0-logloss:0.52200
# [70]	validation_0-logloss:0.52145
# [71]	validation_0-logloss:0.52102
# [72]	validation_0-logloss:0.52018
# [73]	validation_0-logloss:0.51964
# [74]	validation_0-logloss:0.51887
# [75]	validation_0-logloss:0.51840
# [76]	validation_0-logloss:0.51773
# [77]	validation_0-logloss:0.51697
# [78]	validation_0-logloss:0.51626
# [79]	validation_0-logloss:0.51562
# [80]	validation_0-logloss:0.51525
# [81]	validation_0-logloss:0.51495
# [82]	validation_0-logloss:0.51440
# [83]	validation_0-logloss:0.51383
# [84]	validation_0-logloss:0.51333
# [85]	validation_0-logloss:0.51272
# [86]	validation_0-logloss:0.51218
# [87]	validation_0-logloss:0.51169
# [88]	validation_0-logloss:0.51141
# [89]	validation_0-logloss:0.51095
# [90]	validation_0-logloss:0.51063
# [91]	validation_0-logloss:0.51010
# [92]	validation_0-logloss:0.50955
# [93]	validation_0-logloss:0.50917
# [94]	validation_0-logloss:0.50867
# [95]	validation_0-logloss:0.50830
# [96]	validation_0-logloss:0.50804
# [97]	validation_0-logloss:0.50761
# [98]	validation_0-logloss:0.50732
# [99]	validation_0-logloss:0.50664
# [100]	validation_0-logloss:0.50614
# [101]	validation_0-logloss:0.50563
# [102]	validation_0-logloss:0.50518
# [103]	validation_0-logloss:0.50477
# [104]	validation_0-logloss:0.50425
# [105]	validation_0-logloss:0.50380
# [106]	validation_0-logloss:0.50325
# [107]	validation_0-logloss:0.50305
# [108]	validation_0-logloss:0.50258
# [109]	validation_0-logloss:0.50244
# [110]	validation_0-logloss:0.50224
# [111]	validation_0-logloss:0.50181
# [112]	validation_0-logloss:0.50176
# [113]	validation_0-logloss:0.50142
# [114]	validation_0-logloss:0.50108
# [115]	validation_0-logloss:0.50074
# [116]	validation_0-logloss:0.50055
# [117]	validation_0-logloss:0.50046
# [118]	validation_0-logloss:0.50014
# [119]	validation_0-logloss:0.49978
# [120]	validation_0-logloss:0.49932
# [121]	validation_0-logloss:0.49896
# [122]	validation_0-logloss:0.49880
# [123]	validation_0-logloss:0.49847
# [124]	validation_0-logloss:0.49808
# [125]	validation_0-logloss:0.49778
# [126]	validation_0-logloss:0.49760
# [127]	validation_0-logloss:0.49719
# [128]	validation_0-logloss:0.49685
# [129]	validation_0-logloss:0.49655
# [130]	validation_0-logloss:0.49640
# [131]	validation_0-logloss:0.49587
# [132]	validation_0-logloss:0.49546
# [133]	validation_0-logloss:0.49526
# [134]	validation_0-logloss:0.49501
# [135]	validation_0-logloss:0.49474
# [136]	validation_0-logloss:0.49436
# [137]	validation_0-logloss:0.49411
# [138]	validation_0-logloss:0.49375
# [139]	validation_0-logloss:0.49356
# [140]	validation_0-logloss:0.49355
# [141]	validation_0-logloss:0.49327
# [142]	validation_0-logloss:0.49305
# [143]	validation_0-logloss:0.49293
# [144]	validation_0-logloss:0.49257
# [145]	validation_0-logloss:0.49226
# [146]	validation_0-logloss:0.49209
# [147]	validation_0-logloss:0.49177
# [148]	validation_0-logloss:0.49148
# [149]	validation_0-logloss:0.49116
# [150]	validation_0-logloss:0.49087
# [151]	validation_0-logloss:0.49062
# [152]	validation_0-logloss:0.49026
# [153]	validation_0-logloss:0.48984
# [154]	validation_0-logloss:0.48965
# [155]	validation_0-logloss:0.48940
# [156]	validation_0-logloss:0.48913
# [157]	validation_0-logloss:0.48894
# [158]	validation_0-logloss:0.48901
# [159]	validation_0-logloss:0.48882
# [160]	validation_0-logloss:0.48882
# [161]	validation_0-logloss:0.48854
# [162]	validation_0-logloss:0.48836
# [163]	validation_0-logloss:0.48808
# [164]	validation_0-logloss:0.48792
# [165]	validation_0-logloss:0.48783
# [166]	validation_0-logloss:0.48764
# [167]	validation_0-logloss:0.48735
# [168]	validation_0-logloss:0.48700
# [169]	validation_0-logloss:0.48680
# [170]	validation_0-logloss:0.48648
# [171]	validation_0-logloss:0.48622
# [172]	validation_0-logloss:0.48598
# [173]	validation_0-logloss:0.48595
# [174]	validation_0-logloss:0.48570
# [175]	validation_0-logloss:0.48543
# [176]	validation_0-logloss:0.48526
# [177]	validation_0-logloss:0.48510
# [178]	validation_0-logloss:0.48485
# [179]	validation_0-logloss:0.48468
# [180]	validation_0-logloss:0.48456
# [181]	validation_0-logloss:0.48440
# [182]	validation_0-logloss:0.48407
# [183]	validation_0-logloss:0.48388
# [184]	validation_0-logloss:0.48381
# [185]	validation_0-logloss:0.48356
# [186]	validation_0-logloss:0.48335
# [187]	validation_0-logloss:0.48325
# [188]	validation_0-logloss:0.48292
# [189]	validation_0-logloss:0.48296
# [190]	validation_0-logloss:0.48277
# [191]	validation_0-logloss:0.48277
# [192]	validation_0-logloss:0.48242
# [193]	validation_0-logloss:0.48217
# [194]	validation_0-logloss:0.48199
# [195]	validation_0-logloss:0.48166
# [196]	validation_0-logloss:0.48148
# [197]	validation_0-logloss:0.48128
# [198]	validation_0-logloss:0.48104
# [199]	validation_0-logloss:0.48093
